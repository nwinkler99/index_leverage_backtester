# %% [markdown]
# # Investment Dashboard
#
# This notebook loads the dashboard and allocation calculator from `dashboard_utils.py`.

# %%
from IPython.display import display
from dashboard_utils import create_dashboard, create_allocation_calculator

alloc = create_allocation_calculator()
dashboard = create_dashboard(alloc_widget=alloc)

display(dashboard)
